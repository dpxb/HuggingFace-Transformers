# %%
from modelscope.hub.snapshot_download import  snapshot_download

# %%
snapshot_download(model_id="modelscope/Llama-2-7b-ms",cache_dir="D:\Hugging Face Hub\Llama",ignore_file_pattern=".bin")
# Out:
# 2025-11-07 20:58:31,818 - modelscope - WARNING - Model revision not specified, use revision: v1.0.2
# ...
# 2025-11-07 20:58:32,196 - modelscope - INFO - Got 16 files, start to download ...
# Processing 16 items:   0%|          | 0.00/16.0 [00:00<?, ?it/s]
# ...
# 2025-11-07 21:14:23,239 - modelscope - INFO - Download model 'modelscope/Llama-2-7b-ms' successfully.
# 'D:\\Hugging Face Hub\\Llama\\modelscope\\Llama-2-7b-ms'
