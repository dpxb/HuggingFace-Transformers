# %%
#导入相关的包
from transformers import AutoTokenizer, AutoModel, TrainingArguments, Trainer, AutoModelForSequenceClassification
from datasets import load_dataset

# %%
#加载数据集
dataset = load_dataset("json",data_files="./train_pair_1w.json",split="train")
dataset
# Out:
# Dataset({
#     features: ['sentence1', 'sentence2', 'label'],
#     num_rows: 10000
# })

# %%
#划分数据集
datasets = dataset.train_test_split(test_size=0.2)

# %%
#数据集预处理
import torch
tokenizer = AutoTokenizer.from_pretrained("D:\Hugging Face Hub\chinese-macbert-base")
def process_function(examples):
    tokenizer_examples = tokenizer(examples["sentence1"],examples["sentence2"], truncation=True, max_length=128)
    tokenizer_examples["label"] =[ float(i) for i in examples["label"] ]
    return tokenizer_examples
tokenizer_datasets = datasets.map(process_function, batched=True,remove_columns=datasets["train"].column_names)
# Out:
# Map:   0%|          | 0/8000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
#创建模型
model = AutoModelForSequenceClassification.from_pretrained("D:\Hugging Face Hub\chinese-macbert-base",num_labels=1)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at D:\Hugging Face Hub\chinese-macbert-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#创建评估函数
import evaluate
acc_metric = evaluate.load("accuracy")
f1_metric = evaluate.load("f1")
def eval_metric(eval_predict):
    predictions,labels = eval_predict
    predictions =[int(i>0.5) for i in predictions]
    labels =[int(i) for i in labels]
    #predictions = predictions.argmax(dim=-1)
    acc = acc_metric.compute(predictions=predictions, labels=labels)
    f1 = f1_metric.compute(predictions=predictions, labels=labels)
    acc.updata(f1)
    return acc

# %%
#创建TrainingArguments
train_args = TrainingArguments(
    output_dir="./cross_model",
    per_gpu_eval_batch_size=2,
    per_device_train_batch_size=4,
    learning_rate=2e-5,
    weight_decay=0.01,
    save_strategy="epoch",

)

# %%
#创建Trainer
from transformers import DataCollatorWithPadding
trainer = Trainer(
    model=model,
    args=train_args,
    train_dataset=tokenizer_datasets["train"],
    eval_dataset=tokenizer_datasets["test"],
    data_collator=DataCollatorWithPadding(tokenizer=tokenizer),
    compute_metrics=eval_metric,
)

# %%
#模型的训练
trainer.train()
# Out:
#     <div>
#
#       <progress value='3557' max='6000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3557/6000 06:13 < 04:16, 9.51 it/s, Epoch 1.78/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.161200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.129700</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.112800</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.128700</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.082300</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.086000</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.076400</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 2
#       1 #模型的训练
# ----> 2 trainer.train()
#
# File D:\anaconda\ana\envs\PyTorch\lib\site-packages\transformers\trainer.py:2325, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2323         hf_hub_utils.enable_progress_bars()
#    2324 else:
# -> 2325     return inner_training_loop(
#    2326         args=args,
#    2327         resume_from_checkpoint=resume_from_checkpoint,
#    2328         trial=trial,
#    2329         ignore_keys_for_eval=ignore_keys_for_eval,
#    2330     )
#
# File D:\anaconda\ana\envs\PyTorch\lib\site-packages\transformers\trainer.py:2740, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2737     context = implicit_replication
#    2739 with context():
# -> 2740     self.optimizer.step()
#    2742 self.control = self.callback_handler.on_optimizer_step(args, self.state, self.control)
#    2744 # get leaning rate before update
#
# File D:\anaconda\ana\envs\PyTorch\lib\site-packages\accelerate\optimizer.py:179, in AcceleratedOptimizer.step(self, closure)
#     177         self._accelerate_step_called = False
#     178     else:
# --> 179         self.optimizer.step(closure)
#     180 if self.accelerator_state.distributed_type == DistributedType.XLA:
#     181     self.gradient_state.is_xla_gradients_synced = False
#
# File D:\anaconda\ana\envs\PyTorch\lib\site-packages\torch\optim\lr_scheduler.py:140, in LRScheduler.__init__.<locals>.patch_track_step_called.<locals>.wrap_step.<locals>.wrapper(*args, **kwargs)
#     138 opt = opt_ref()
#     139 opt._opt_called = True  # type: ignore[union-attr]
# --> 140 return func.__get__(opt, opt.__class__)(*args, **kwargs)
#
# File D:\anaconda\ana\envs\PyTorch\lib\site-packages\torch\optim\optimizer.py:493, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     488         else:
#     489             raise RuntimeError(
#     490                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     491             )
# --> 493 out = func(*args, **kwargs)
#     494 self._optimizer_step_code()
#     496 # call optimizer step post hooks
#
# File D:\anaconda\ana\envs\PyTorch\lib\site-packages\torch\optim\optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      89     torch.set_grad_enabled(self.defaults["differentiable"])
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
#
# File D:\anaconda\ana\envs\PyTorch\lib\site-packages\torch\optim\adamw.py:243, in AdamW.step(self, closure)
#     230     beta1, beta2 = cast(Tuple[float, float], group["betas"])
#     232     has_complex = self._init_group(
#     233         group,
#     234         params_with_grad,
#    (...)
#     240         state_steps,
#     241     )
# --> 243     adamw(
#     244         params_with_grad,
#     245         grads,
#     246         exp_avgs,
#     247         exp_avg_sqs,
#     248         max_exp_avg_sqs,
#     249         state_steps,
#     250         amsgrad=amsgrad,
#     251         beta1=beta1,
#     252         beta2=beta2,
#     253         lr=group["lr"],
#     254         weight_decay=group["weight_decay"],
#     255         eps=group["eps"],
#     256         maximize=group["maximize"],
#     257         foreach=group["foreach"],
#     258         capturable=group["capturable"],
#     259         differentiable=group["differentiable"],
#     260         fused=group["fused"],
#     261         grad_scale=getattr(self, "grad_scale", None),
#     262         found_inf=getattr(self, "found_inf", None),
#     263         has_complex=has_complex,
#     264     )
#     266 return loss
#
# File D:\anaconda\ana\envs\PyTorch\lib\site-packages\torch\optim\optimizer.py:154, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     152     return disabled_func(*args, **kwargs)
#     153 else:
# --> 154     return func(*args, **kwargs)
#
# File D:\anaconda\ana\envs\PyTorch\lib\site-packages\torch\optim\adamw.py:875, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     872 else:
#     873     func = _single_tensor_adamw
# --> 875 func(
#     876     params,
#     877     grads,
#     878     exp_avgs,
#     879     exp_avg_sqs,
#     880     max_exp_avg_sqs,
#     881     state_steps,
#     882     amsgrad=amsgrad,
#     883     beta1=beta1,
#     884     beta2=beta2,
#     885     lr=lr,
#     886     weight_decay=weight_decay,
#     887     eps=eps,
#     888     maximize=maximize,
#     889     capturable=capturable,
#     890     differentiable=differentiable,
#     891     grad_scale=grad_scale,
#     892     found_inf=found_inf,
#     893     has_complex=has_complex,
#     894 )
#
# File D:\anaconda\ana\envs\PyTorch\lib\site-packages\torch\optim\adamw.py:699, in _multi_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, has_complex)
#     697     exp_avg_sq_sqrt = torch._foreach_sqrt(device_max_exp_avg_sqs)
#     698 else:
# --> 699     exp_avg_sq_sqrt = torch._foreach_sqrt(device_exp_avg_sqs)
#     701 torch._foreach_div_(exp_avg_sq_sqrt, bias_correction2_sqrt)
#     702 torch._foreach_add_(exp_avg_sq_sqrt, eps)
#
# KeyboardInterrupt:

# %%
from transformers import pipeline
model.config.id2label = {0:"不相似",1:"相似"}
pipe = pipeline("text-classification",model = model,tokenizer=tokenizer,device=0)
# Out:
# Device set to use cuda:0

# %%
pipe({"text":"我喜欢北京","text_pair":"北京真好我喜欢这"})
# Out:
# {'label': '相似', 'score': 0.9898111820220947}
